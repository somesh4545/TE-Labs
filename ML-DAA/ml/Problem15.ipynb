# %% [markdown]
# Market Basket Analysis: Apriori Algorithm
# Dataset: Order1.csv
# The dataset has 38765 rows of the purchase orders of people from the
# grocery stores. These orders can be analysed, and association rules can
# be generated using Market Basket Analysis by algorithms like Apriori
# Algorithm.
# Follow following Steps:
# a. Data Pre-processing
# b. Generate the list of transactions fromthe dataset
# c. Train Apriori on the dataset
# d. Visualize the list of datasets

# %%
# !pip install apyori
import pandas as pd
import numpy as np
from apyori import apriori

# %%
df = pd.read_csv('/content/Order1.csv')
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df.shape
# Out:
# (38765, 3)

# %%
len(df['Member_number'].unique())
# Out:
# 3898

# %%
transcation = df.groupby(['Member_number', 'Date']).agg({'itemDescription': ', '.join}).reset_index()
transcation.head()
# Out:
#    Member_number        Date                                   itemDescription
# 0           1000  15-03-2015  sausage, whole milk, semi-finished bread, yogurt
# 1           1000  24-06-2014                   whole milk, pastry, salty snack
# 2           1000  24-07-2015                      canned beer, misc. beverages
# 3           1000  25-11-2015                         sausage, hygiene articles
# 4           1000  27-05-2015                          soda, pickled vegetables

# %%
transcation.shape
# Out:
# (14963, 3)

# %%
records = []
for i in range(1, 14963):
  lis = []
  for item in transcation['itemDescription'][i].split(', '):
    lis.append(item)
  records.append(lis)

# %%
association_rules = apriori(records, min_support=0.005, min_confidence=0.01, min_lift=1, min_length=3)
rules = list(association_rules)
len(rules)
# Out:
# 72

# %%
for rule in rules:
  pair = item[0]
  items = [x for x in pair]
  print(rule)
  if len(items)>=2:
    print("Rule: " + items[0] + " -> " + items[1])
    # second index of the inner list
    print("Support: " + str(item[1]))
    # third index of the list located at 0th position
    # of the third index of the inner list
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("-----------------------------------------------------")
# Out:
# RelationRecord(items=frozenset({'UHT-milk'}), support=0.02138751503809651, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'UHT-milk'}), confidence=0.02138751503809651, lift=1.0)])
# RelationRecord(items=frozenset({'beef'}), support=0.03395268012297821, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'beef'}), confidence=0.03395268012297821, lift=1.0)])
# RelationRecord(items=frozenset({'berries'}), support=0.02178853094506082, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'berries'}), confidence=0.02178853094506082, lift=1.0)])
# RelationRecord(items=frozenset({'beverages'}), support=0.016575324154524795, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'beverages'}), confidence=0.016575324154524795, lift=1.0)])
# ...
